# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as mpl

# %%
mpl.rcParams["font.sans-serif"] = ["FangSong"]
mpl.rcParams["axes.unicode_minus"] = False

# %%
_df1 = pd.read_csv(r"E:\news_data\社交距离\5040_2_20210921205024.csv")
df1 = pd.read_csv(r"E:\news_data\社交距离\5040_3_20210922180938.csv")
df2 = pd.read_csv(r"E:\news_data\口罩防护\5040_08_20210922222320.csv")
df3 = pd.read_csv(r"E:\news_data\口罩防护\5040_04_20210922132433.csv")

# %%
plt.figure(figsize=(14,11))
plt.plot(_df1["i_ratio"],label = "限制社交距离=2",linewidth=4,color="#589BAD")
plt.plot(df1["i_ratio"],label = "限制社交距离=3",color="#FAA055",linewidth=4)
plt.plot(df3["i_ratio"],"--",label = "口罩覆盖率=0.4",color="#CE466A",linewidth=4)
plt.plot(df2["i_ratio"],"--",label = "口罩覆盖率=0.8",color="#9ED532",linewidth=4)

plt.xlabel(xlabel="时间步",fontsize=40,labelpad=15)
plt.ylabel(ylabel="感染者比例",fontsize=40,labelpad=15)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.legend(fontsize=32)

# %%
(hex(158),hex(213),hex(50))
# Out:
# ('0x9e', '0xd5', '0x32')
