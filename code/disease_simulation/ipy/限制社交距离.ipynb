# %%
import pandas as pd
import matplotlib.pyplot as plt
import pylab as mpl

# %%
mpl.rcParams["font.sans-serif"]=["FangSong"]	#设置字体为仿宋
mpl.rcParams["axes.unicode_minus"]=False		#解决负号显示错误问题

# %%
df1 = pd.read_csv(r"D:\code\disease_simulation\log\log1\5040_0_20210922132016.csv")
df2 = pd.read_csv(r"D:\code\disease_simulation\log\log1\5040_1_20210922132016.csv")
df3 = pd.read_csv(r"D:\code\disease_simulation\log\log1\5040_2_20210921205024.csv")
df4 = pd.read_csv(r"D:\code\disease_simulation\log\log1\5040_3_20210922180938.csv")

# %%
plt.figure(figsize=(14,11))
plt.xlabel(xlabel="时间步",fontsize=40,labelpad=15)
plt.ylabel(ylabel="感染者比例",fontsize=40,labelpad=15)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.plot(df2["i_ratio"],label = "限制社交距离=1",color="#CE466A",linewidth=4)
plt.plot(df3["i_ratio"],label = "限制社交距离=2",color="#589BAD",linewidth=4)
plt.plot(df4["i_ratio"],label = "限制社交距离=3",color="#FAA055",linewidth=4)
plt.legend(fontsize=32)

# %%
_df1 = pd.read_csv(r"D:\code\disease_simulation\log\5040_0_20210922232346.csv")
_df2 = pd.read_csv(r"D:\code\disease_simulation\log\5040_1_20210922103847.csv")

# %%
plt.figure(figsize=(20,20))
plt.plot(_df1["i_ratio"],label =0 )
plt.plot(_df2["i_ratio"],label =1 )
plt.legend()
